# %%
EVENT_OUT = 1
EVENT_IN = -1

with open('input.txt', 'r') as f:
    n,m = map(int, f.readline().split())
    events = []
    
    for _ in range(m):
        b, e = map(int, f.readline().split())
        events += [(b, EVENT_IN), (e, EVENT_OUT)]

events.sort()

cnt = 0
last_p = 0
cnt_in = 0
cnt_out = 0

for p, ev in events:
    if ev == EVENT_IN:
        if cnt_in == cnt_out:
            cnt_in += 1
            cnt+= p - last_p
        elif cnt_in > cnt_out:
            cnt_in += 1
    elif ev == EVENT_OUT: 
        cnt_out+= 1
        
        if cnt_in == cnt_out:
            last_p = p+1
print(cnt + n - last_p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a0b571ef9c79> in <module>
#       3
#       4 with open('input.txt', 'r') as f:
# ----> 5     n,m = map(int, f.readline().split())
#       6     events = []
#       7
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
EVENT_OUT = 1
EVENT_IN = -1
EVENT_NONE = 0

with open('input.txt', 'r') as f:
    n,m = map(int, f.readline().split())
    events = []
    
    for _ in range(n):
        a,b = sorted(map(int, f.readline().split()))
        
        events += [(a, EVENT_IN), (b, EVENT_OUT)]
    
    arrm = list(map(int, f.readline().split()))
    
for e in arrm:
    events += [(e, EVENT_NONE)]
events.sort()

cnts = dict()
cnt = 0

for point, e in events:
    if e == EVENT_NONE:
        cnts[point] = cnt
    elif e == EVENT_IN:
        cnt+=1
    elif e == EVENT_OUT:
        cnt -= 1
res = []

for p in arrm:
    res += [cnts[p]]
    
print(*res)

# %%
with open('input.txt', 'r') as f: 
    n,d = map(int, f.readline().split())
    arr = list(map(int, f.readline().split()))

for i in range(n):
    arr[i] = (arr[i], i)
arr.sort()    
 
L,R = 0, 1
min_t = 0

while R < n:
    next_place = arr[L][0] + d
    
    while R < n and arr[R][0] <= next_place:
        R+=1
    
    min_t = max(min_t, R-L)
    L+=1
    R+=1
    
v = [1 for _ in range(n)]
i = 0

for place, index in arr:
    v[index] = i % min_t+1 # I have no idea why it works
    i+=1
    
print(min_t)
print(*v)

# %%
EVENT_OUT = 1
EVENT_IN = -1

with open('input.txt', 'r') as f: 
    n = int(f.readline())
    events = []
    
    for i in range(n):
        in_, out_ = map(int, f.readline().split())
        
        if out_ - in_ >= 5:
            events += [(in_, EVENT_IN, i), (out_-5, EVENT_OUT, i)]
events.sort()        

n = len(events) 

if n == 0:
    print(0, 1, 6)
elif n == 2:
    print(1, events[0][0], events[0][0] + 5)
else:
    s = set()
    max_cnt = 0
    best1, best2 = 0,0
    
    for i in range(n):
        first = events[i]
        if first[1] == EVENT_IN:
            s.add(first[2])
            if len(s) > max_cnt:
                max_cnt = len(s)
                best1, best2 = first[0], first[0] + 5
        cnt2 = 0    
        for j in range(i+1, n):
            second = events[j]
            
            if second[1] == EVENT_IN:
                cnt2 += 1
            if second[0] - first[0] >= 5 and len(s)+cnt2 > max_cnt:
                max_cnt = len(s)+cnt2
                best1, best2 = first[0],second[0]
            if second[1] == EVENT_OUT and second[2] not in s:
                cnt2 -=1   
        if first[1] == EVENT_OUT:
            s.remove(first[2])
        
    print(max_cnt, best1, best2)

# %%
IN = -1
OUT = 1

with open('input.txt', 'r') as f:
    n = int(f.readline())
    events = []
    
    for i in range(n):
        h_start, m_start, h_end, m_end = map(int, f.readline().split())
        
        if (h_start, m_start) > (h_end, m_end):
            events += [((24, 0), OUT), ((0,0), IN)]
            events += [((h_start, m_start), IN), ((h_end, m_end), OUT)]
        elif (h_start, m_start) == (h_end, m_end):
            events += [((24, 0), OUT), ((0,0), IN)]
        else:
            events += [((h_start, m_start), IN), ((h_end, m_end), OUT)]
    
events.sort()

cnt = 0
ans = 0

for time, ev in events:
    if ev == IN:
        cnt+=1
        last_in = time
    elif ev == OUT:
        if cnt == n:
            ans += 60*(time[0] - last_in[0]) + time[1] - last_in[1]
        cnt -= 1
print(ans)

# %%
import datetime

IN = 1
OUT = -1

with open('input.txt', 'r') as f:
    n = int(f.readline())
    events = []
    people = []
    
    for i in range(n):
        d_birth, m_birth, y_birth, d_death, m_death, y_death = map(int, f.readline().split())
        
        birth = datetime.date(y_birth+18,m_birth,d_birth)
        death = min(datetime.date(y_birth+80,m_death,d_death), datetime.date(y_death,m_death,d_death))
        
        if death > birth:
            events += [(birth, IN, i+1), (death, OUT, i+1)]
            
events.sort()

if len(events) == 0:
    print(0)
else:
    s = set()
    for time, ev, i in events:
        if ev == IN:
            s.add(i)
            rest = False
        elif ev == OUT:
            if rest:
                s.discard(i)
            else:
                print(*s)
                s.discard(i)
                rest = True
# Out:
# 3 35 37 40 41 13 45 16 17 19
# 3 35 37 7 40 41 8 13 47 16 17 15 19 23
# 3 7 8 15 16 18 19 21 22 23 24 35 36 37 40 41 42 47 48 49
# 3 7 8 10 15 16 18 19 21 22 23 24 25 35 36 40 41 42 47 48 49
# 3 7 8 9 10 15 16 18 19 21 22 24 35 40 41 42 47 48 49
# 3 7 8 9 10 14 15 16 18 19 21 22 24 35 42 47 48 49
# 3 5 7 8 9 10 11 14 15 18 19 21 24 35 42 47 48 49
# 3 5 7 8 9 10 11 14 15 18 21 24 35 39 42 47 48 49
# 7 8 9 10 11 14 15 18 21 24 27 35 39 42 47 48 49
# 7 8 9 10 11 14 15 18 21 24 27 30 39 42 47 48 49
# 7 9 10 11 14 15 18 21 24 27 30 39 42 48 50
# 9 10 11 14 15 18 21 24 27 29 30 39 42 48 50
# 4 9 10 11 14 15 18 21 24 27 28 29 30 42 48 50
# 4 6 14 18 21 24 27 28 29 30 42 48 50
# 4 6 14 18 24 27 28 29 30 42 46 50
# 4 6 14 27 28 29 30 34 46 50
# 6 14 20 27 28 29 30 31 33 34 44 46 50
# 2 6 28 29 30 31 33 44 46 50

# %%
import matplotlib.pyplot as plt

# %%
# plt.margins(0.05) # So the lines aren't at the plot boundaries..
plt.figure(figsize=(14, 8), dpi=80)

for i in range(1, n+1):
    if i in [e[2] for e in events]:
        start = [e for e in events if e[1] == -1 and e[2] == i][0]
        end = [e for e in events if e[1] == 1 and e[2] == i][0]
        
        x_min, x_max = start[0], end[0]
        y = i
        plt.hlines(y, x_min, x_max, color='black', linewidth=2, label=str(i))

# %%
events
# Out:
# [(datetime.date(1012, 8, 9), 1, 45),
#  (datetime.date(1013, 10, 20), 1, 13),
#  (datetime.date(1016, 7, 19), 1, 40),
#  (datetime.date(1022, 11, 1), 1, 41),
#  (datetime.date(1023, 12, 1), 1, 17),
#  (datetime.date(1023, 12, 7), 1, 16),
#  (datetime.date(1026, 12, 8), 1, 37),
#  (datetime.date(1027, 10, 24), 1, 19),
#  (datetime.date(1030, 5, 14), 1, 3),
#  (datetime.date(1032, 3, 26), 1, 35),
#  (datetime.date(1032, 6, 21), -1, 45),
#  (datetime.date(1034, 1, 16), 1, 23),
#  (datetime.date(1034, 4, 26), 1, 8),
#  (datetime.date(1034, 8, 4), 1, 47),
#  (datetime.date(1036, 10, 20), 1, 7),
#  (datetime.date(1039, 1, 8), 1, 15),
#  (datetime.date(1039, 3, 20), -1, 17),
#  (datetime.date(1041, 7, 10), -1, 13),
#  (datetime.date(1045, 10, 5), 1, 49),
#  (datetime.date(1049, 12, 4), 1, 36),
#  (datetime.date(1050, 4, 10), 1, 21),
#  (datetime.date(1055, 6, 2), 1, 18),
#  (datetime.date(1056, 1, 12), 1, 24),
#  (datetime.date(1057, 4, 2), 1, 22),
#  (datetime.date(1059, 6, 21), 1, 42),
#  (datetime.date(1061, 12, 20), 1, 48),
#  (datetime.date(1062, 12, 22), -1, 37),
#  (datetime.date(1067, 2, 24), 1, 25),
#  (datetime.date(1068, 8, 10), 1, 10),
#  (datetime.date(1070, 12, 17), -1, 36),
#  (datetime.date(1073, 10, 15), -1, 25),
#  (datetime.date(1074, 4, 16), -1, 23),
#  (datetime.date(1075, 8, 9), 1, 9),
#  (datetime.date(1078, 8, 11), -1, 40),
#  (datetime.date(1084, 1, 5), -1, 41),
#  (datetime.date(1085, 6, 23), 1, 14),
#  (datetime.date(1085, 7, 26), -1, 16),
#  (datetime.date(1086, 10, 10), -1, 22),
#  (datetime.date(1086, 10, 17), 1, 5),
#  (datetime.date(1088, 4, 4), 1, 11),
#  (datetime.date(1089, 11, 20), -1, 19),
#  (datetime.date(1090, 2, 9), 1, 39),
#  (datetime.date(1090, 7, 14), -1, 5),
#  (datetime.date(1092, 8, 24), -1, 3),
#  (datetime.date(1094, 9, 14), 1, 27),
#  (datetime.date(1094, 11, 16), -1, 35),
#  (datetime.date(1095, 11, 6), 1, 30),
#  (datetime.date(1096, 2, 18), -1, 47),
#  (datetime.date(1096, 5, 14), -1, 8),
#  (datetime.date(1096, 11, 24), -1, 49),
#  (datetime.date(1098, 8, 3), 1, 50),
#  (datetime.date(1098, 8, 19), -1, 7),
#  (datetime.date(1098, 12, 12), 1, 29),
#  (datetime.date(1101, 1, 4), -1, 39),
#  (datetime.date(1101, 2, 9), 1, 28),
#  (datetime.date(1101, 8, 14), 1, 4),
#  (datetime.date(1101, 11, 19), -1, 15),
#  (datetime.date(1102, 12, 8), -1, 10),
#  (datetime.date(1102, 12, 20), -1, 9),
#  (datetime.date(1104, 12, 27), -1, 11),
#  (datetime.date(1107, 6, 20), 1, 6),
#  (datetime.date(1112, 4, 11), -1, 21),
#  (datetime.date(1113, 8, 26), -1, 48),
#  (datetime.date(1116, 11, 8), 1, 46),
#  (datetime.date(1117, 9, 20), -1, 18),
#  (datetime.date(1118, 6, 1), -1, 24),
#  (datetime.date(1121, 1, 3), -1, 42),
#  (datetime.date(1126, 2, 10), 1, 34),
#  (datetime.date(1127, 6, 13), -1, 4),
#  (datetime.date(1130, 1, 17), 1, 20),
#  (datetime.date(1134, 11, 15), 1, 44),
#  (datetime.date(1135, 2, 16), 1, 31),
#  (datetime.date(1139, 9, 24), 1, 33),
#  (datetime.date(1142, 8, 15), -1, 34),
#  (datetime.date(1143, 9, 24), -1, 20),
#  (datetime.date(1147, 6, 19), -1, 14),
#  (datetime.date(1148, 10, 8), -1, 27),
#  (datetime.date(1150, 6, 11), 1, 2),
#  (datetime.date(1157, 7, 14), -1, 44),
#  (datetime.date(1157, 9, 6), -1, 30),
#  (datetime.date(1160, 8, 22), -1, 50),
#  (datetime.date(1160, 12, 15), -1, 29),
#  (datetime.date(1163, 4, 18), -1, 28),
#  (datetime.date(1169, 6, 22), -1, 6),
#  (datetime.date(1172, 12, 10), -1, 2),
#  (datetime.date(1175, 5, 7), -1, 31),
#  (datetime.date(1177, 1, 15), -1, 46),
#  (datetime.date(1179, 7, 25), -1, 33)]
